# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:79fd8319-e691-4331-9809-414b46ba737d.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](attachment:8b36cc92-ebbf-4c82-99f8-b3df7fae5339.png)

# %% [markdown]
# **Objectives:**
# - Popular languages used for DataScience
# - Popular tools
# - Math operations

# %% [markdown]
# ![10-objectives.png](attachment:f83b9bce-cd72-4c4f-8513-a9a85ad22ddb.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# ![4-dslanguages.png](attachment:b1108681-c194-4999-9dbe-86046b609579.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. MatPlotLib
# 4. SciPy

# %% [markdown]
# ![5-dslibraries.png](attachment:220488d3-3ab9-4cbf-955b-a549d653efdf.png)

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |GIT|
# |Spyder|
# |Jupyter|
# |RStudio|
# |Anaconda|

# %% [markdown]
# ![6-dstools.png](attachment:aa260645-97ad-4a03-a69d-07c1765f29b5.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# - *+*
# - *-*
# - */*
# - *//*

# %% [markdown]
# ![7-introarithmetic.png](attachment:7c819acc-54ec-415e-94b7-4e7b99ab9982.png)

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:4217eec9-15c1-45a7-9774-0b8b94d9e42f.png)

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
minutes=200
hours=minutes/60
print (hours)
print (int(hours))
# Out:
# 3.3333333333333335
# 3

# %% [markdown]
# ![9-hourstominutes.png](attachment:4a2fdbd3-8ba5-44f8-b865-9c61193315bd.png)

# %% [markdown]
# ## Author
# Michal Kuruc

# %% [markdown]
# ![11-authordetails.png](attachment:a852ddc9-25ed-42f1-8075-ee34483e9d64.png)
